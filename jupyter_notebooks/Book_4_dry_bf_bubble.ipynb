# %% [markdown]
# # Notebook 4: Dry bf bubble

# %% [markdown]
# The dry df bubble example. This considers the idea of recovery. This is where we wish to solve for a higher order field around the object of interest, which in this case, is a dry bubble.

# %% [markdown]
# We begin by importing the required libraries and functions from Firedrake and Gusto:

# %%
from gusto import *
from firedrake import (IntervalMesh, ExtrudedMesh,
                       SpatialCoordinate, conditional, cos, pi, sqrt,
                       TestFunction, dx, TrialFunction, Constant, Function,
                       LinearVariationalProblem, LinearVariationalSolver,
                       FunctionSpace, BrokenElement, VectorFunctionSpace)
from firedrake.slope_limiter.vertex_based_limiter import VertexBasedLimiter
import sys

# %% [markdown]
# We now define the time-step size and simulation time.

# %%
dt = 1.0
deltax = 100.
tmax = 1000.

# %% [markdown]
# Make the mesh. This is an interval mesh that we extrude in the vertical direction.

# %%
L = 10000.
H = 10000.
nlayers = int(H/deltax)
ncolumns = int(L/deltax)
m = IntervalMesh(ncolumns, L)
mesh = ExtrudedMesh(m, layers=nlayers, layer_height=H/nlayers)

# %% [markdown]
# Define the lowest order degree in this recovered case.

# %%
# options
diffusion = False
degree = 0

# %% [markdown]
# Define the output. We will record the full velocity fields, as well as the perturbations to the potential temperature.

# %%
dirname = 'dry_bf_bubble_recovered'

output = OutputParameters(dirname=dirname,
                          dumpfreq=int(tmax / (5*dt)),
                          dumplist=['u'],
                          perturbation_fields=['theta'],
                          log_level='INFO')

# %% [markdown]
# Set up the state, using parameters corresponding to a compressible set-up.

# %%
params = CompressibleParameters()

state = State(mesh,
              dt=dt,
              output=output,
              parameters=params)
# Out:
# gusto:INFO Physical parameters that take non-default values:
# gusto:INFO

# %% [markdown]
# Define the equations to solve, which are the compressible Euler equations. We neglect any diffusion options for this simulation.

# %%
diffusion_options = None

u_transport_option = "vector_advection_form" 

eqns = CompressibleEulerEquations(state, "CG", degree,
                                  u_transport_option=u_transport_option,
                                  diffusion_options=diffusion_options,
                                  no_normal_flow_bc_ids=[1, 2])

# %% [markdown]
# Define the initial conditions and the function spaces.

# %%
# Initial conditions
u0 = state.fields("u")
rho0 = state.fields("rho")
theta0 = state.fields("theta")

# spaces
Vu = state.spaces("HDiv")
Vt = state.spaces("theta")
Vr = state.spaces("DG")
x, z = SpatialCoordinate(mesh)

# %% [markdown]
# Initialise the state to be in hydrostatic balance

# %%
# Define constant theta_e and water_t
Tsurf = 300.0
theta_b = Function(Vt).interpolate(Constant(Tsurf))

# Calculate hydrostatic fields
compressible_hydrostatic_balance(state, theta_b, rho0, solve_for_rho=True)

# %% [markdown]
# More set up for the initial conditions

# %%
# make mean fields
rho_b = Function(Vr).assign(rho0)

# define perturbation
xc = L / 2
zc = 2000.
rc = 2000.
Tdash = 2.0
r = sqrt((x - xc) ** 2 + (z - zc) ** 2)
theta_pert = Function(Vt).interpolate(conditional(r > rc,
                                                  0.0,
                                                  Tdash * (cos(pi * r / (2.0 * rc))) ** 2))

# define initial theta
theta0.assign(theta_b * (theta_pert / 300.0 + 1.0))
# Out:
# Coefficient(WithGeometry(IndexedProxyFunctionSpace(<firedrake.mesh.ExtrudedMeshTopology object at 0x7f8c62e5e3a0>, TensorProductElement(FiniteElement('Discontinuous Lagrange', interval, 0, variant='equispaced'), FiniteElement('Lagrange', interval, 1, variant='equispaced'), cell=TensorProductCell(interval, interval)), name='Vtheta', index=2, component=None), Mesh(VectorElement(TensorProductElement(FiniteElement('Lagrange', interval, 1), FiniteElement('Lagrange', interval, 1), cell=TensorProductCell(interval, interval)), dim=2), 4)), 14)

# %% [markdown]
# More set up and pass this information to the state instance.

# %%
# find perturbed rho
gamma = TestFunction(Vr)
rho_trial = TrialFunction(Vr)
lhs = gamma * rho_trial * dx
rhs = gamma * (rho_b * theta_b / theta0) * dx
rho_problem = LinearVariationalProblem(lhs, rhs, rho0)
rho_solver = LinearVariationalSolver(rho_problem)
rho_solver.solve()

state.set_reference_profiles([('rho', rho_b),
                              ('theta', theta_b)])

# %% [markdown]
# Set up the transport schemes

# %%
VDG1 = state.spaces("DG1", "DG", 1)
VCG1 = FunctionSpace(mesh, "CG", 1)
Vt_brok = FunctionSpace(mesh, BrokenElement(Vt.ufl_element()))
Vu_DG1 = VectorFunctionSpace(mesh, VDG1.ufl_element())
Vu_CG1 = VectorFunctionSpace(mesh, "CG", 1)
Vu_brok = FunctionSpace(mesh, BrokenElement(Vu.ufl_element()))

u_opts = RecoveredOptions(embedding_space=Vu_DG1,
                          recovered_space=Vu_CG1,
                          broken_space=Vu_brok,
                          boundary_method=Boundary_Method.dynamics)
rho_opts = RecoveredOptions(embedding_space=VDG1,
                            recovered_space=VCG1,
                            broken_space=Vr,
                            boundary_method=Boundary_Method.dynamics)
theta_opts = RecoveredOptions(embedding_space=VDG1,
                              recovered_space=VCG1,
                              broken_space=Vt_brok)

# %% [markdown]
# Set up the time-stepping choices for the transported fields. We will use SSPRK3 for all prognostic variables.

# %%
limiter = None

transported_fields = [SSPRK3(state, "u", options=u_opts),
                      SSPRK3(state, "rho", options=rho_opts),
                      SSPRK3(state, "theta", options=theta_opts, limiter=limiter)]

# %% [markdown]
# Set up the linear solver and the time-stepper. We don't need to have any diffusion schemes.

# %%
# Set up linear solver
linear_solver = CompressibleSolver(state, eqns)

diffusion_schemes = []

# build time stepper
stepper = CrankNicolson(state, eqns, transported_fields,
                        linear_solver=linear_solver,
                        diffusion_schemes=diffusion_schemes)

# %% [markdown]
# Run!

# %%
stepper.run(t=0, tmax=tmax)
# Out:
# /home/timandrews/firedrake/src/firedrake/firedrake/checkpointing.py:89: DeprecationWarning: DumbCheckpoint class will be deprecated after 01/01/2023; use CheckpointFile class instead.
#   warnings.warn("DumbCheckpoint class will be deprecated after 01/01/2023; use CheckpointFile class instead.",
# gusto:INFO at start of timestep, t=0, dt=1.0
# tsfc:WARNING Estimated quadrature degree (11, 11) more than tenfold greater than any argument/coefficient degree (max (1, 1))
# tsfc:WARNING Estimated quadrature degree (12, 12) more than tenfold greater than any argument/coefficient degree (max (1, 1))
# tsfc:WARNING Estimated quadrature degree (11, 11) more than tenfold greater than any argument/coefficient degree (max (1, 1))
# tsfc:WARNING Estimated quadrature degree (11, 12) more than tenfold greater than any argument/coefficient degree (max (1, 1))
# gusto:INFO at start of timestep, t=1.0, dt=1.0
# gusto:INFO at start of timestep, t=2.0, dt=1.0
# gusto:INFO at start of timestep, t=3.0, dt=1.0
# gusto:INFO at start of timestep, t=4.0, dt=1.0
# gusto:INFO at start of timestep, t=5.0, dt=1.0
# gusto:INFO at start of timestep, t=6.0, dt=1.0
# gusto:INFO at start of timestep, t=7.0, dt=1.0
# gusto:INFO at start of timestep, t=8.0, dt=1.0
# gusto:INFO at start of timestep, t=9.0, dt=1.0
# gusto:INFO at start of timestep, t=10.0, dt=1.0
# gusto:INFO at start of timestep, t=11.0, dt=1.0
# gusto:INFO at start of timestep, t=12.0, dt=1.0
# gusto:INFO at start of timestep, t=13.0, dt=1.0
# gusto:INFO at start of timestep, t=14.0, dt=1.0
# gusto:INFO at start of timestep, t=15.0, dt=1.0
# gusto:INFO at start of timestep, t=16.0, dt=1.0
# gusto:INFO at start of timestep, t=17.0, dt=1.0
# gusto:INFO at start of timestep, t=18.0, dt=1.0
# gusto:INFO at start of timestep, t=19.0, dt=1.0
# gusto:INFO at start of timestep, t=20.0, dt=1.0
# gusto:INFO at start of timestep, t=21.0, dt=1.0
# gusto:INFO at start of timestep, t=22.0, dt=1.0
# gusto:INFO at start of timestep, t=23.0, dt=1.0
# gusto:INFO at start of timestep, t=24.0, dt=1.0
# gusto:INFO at start of timestep, t=25.0, dt=1.0
# gusto:INFO at start of timestep, t=26.0, dt=1.0
# gusto:INFO at start of timestep, t=27.0, dt=1.0
# gusto:INFO at start of timestep, t=28.0, dt=1.0
# gusto:INFO at start of timestep, t=29.0, dt=1.0
# gusto:INFO at start of timestep, t=30.0, dt=1.0
# gusto:INFO at start of timestep, t=31.0, dt=1.0
# gusto:INFO at start of timestep, t=32.0, dt=1.0
# gusto:INFO at start of timestep, t=33.0, dt=1.0
# gusto:INFO at start of timestep, t=34.0, dt=1.0
# gusto:INFO at start of timestep, t=35.0, dt=1.0
# gusto:INFO at start of timestep, t=36.0, dt=1.0
# gusto:INFO at start of timestep, t=37.0, dt=1.0
# gusto:INFO at start of timestep, t=38.0, dt=1.0
# gusto:INFO at start of timestep, t=39.0, dt=1.0
# gusto:INFO at start of timestep, t=40.0, dt=1.0
# gusto:INFO at start of timestep, t=41.0, dt=1.0
# gusto:INFO at start of timestep, t=42.0, dt=1.0
# gusto:INFO at start of timestep, t=43.0, dt=1.0
# gusto:INFO at start of timestep, t=44.0, dt=1.0
# gusto:INFO at start of timestep, t=45.0, dt=1.0
# gusto:INFO at start of timestep, t=46.0, dt=1.0
# gusto:INFO at start of timestep, t=47.0, dt=1.0
# gusto:INFO at start of timestep, t=48.0, dt=1.0
# gusto:INFO at start of timestep, t=49.0, dt=1.0
# gusto:INFO at start of timestep, t=50.0, dt=1.0
# gusto:INFO at start of timestep, t=51.0, dt=1.0
# gusto:INFO at start of timestep, t=52.0, dt=1.0
# gusto:INFO at start of timestep, t=53.0, dt=1.0
# gusto:INFO at start of timestep, t=54.0, dt=1.0
# gusto:INFO at start of timestep, t=55.0, dt=1.0
# gusto:INFO at start of timestep, t=56.0, dt=1.0
# gusto:INFO at start of timestep, t=57.0, dt=1.0
# gusto:INFO at start of timestep, t=58.0, dt=1.0
# gusto:INFO at start of timestep, t=59.0, dt=1.0
# gusto:INFO at start of timestep, t=60.0, dt=1.0
# gusto:INFO at start of timestep, t=61.0, dt=1.0
# gusto:INFO at start of timestep, t=62.0, dt=1.0
# gusto:INFO at start of timestep, t=63.0, dt=1.0
# gusto:INFO at start of timestep, t=64.0, dt=1.0
# gusto:INFO at start of timestep, t=65.0, dt=1.0
# gusto:INFO at start of timestep, t=66.0, dt=1.0
# gusto:INFO at start of timestep, t=67.0, dt=1.0
# gusto:INFO at start of timestep, t=68.0, dt=1.0
# gusto:INFO at start of timestep, t=69.0, dt=1.0
# gusto:INFO at start of timestep, t=70.0, dt=1.0
# gusto:INFO at start of timestep, t=71.0, dt=1.0
# gusto:INFO at start of timestep, t=72.0, dt=1.0
# gusto:INFO at start of timestep, t=73.0, dt=1.0
# gusto:INFO at start of timestep, t=74.0, dt=1.0
# gusto:INFO at start of timestep, t=75.0, dt=1.0
# gusto:INFO at start of timestep, t=76.0, dt=1.0
# gusto:INFO at start of timestep, t=77.0, dt=1.0
# gusto:INFO at start of timestep, t=78.0, dt=1.0
# gusto:INFO at start of timestep, t=79.0, dt=1.0
# gusto:INFO at start of timestep, t=80.0, dt=1.0
# gusto:INFO at start of timestep, t=81.0, dt=1.0
# gusto:INFO at start of timestep, t=82.0, dt=1.0
# gusto:INFO at start of timestep, t=83.0, dt=1.0
# gusto:INFO at start of timestep, t=84.0, dt=1.0
# gusto:INFO at start of timestep, t=85.0, dt=1.0
# gusto:INFO at start of timestep, t=86.0, dt=1.0
# gusto:INFO at start of timestep, t=87.0, dt=1.0
# gusto:INFO at start of timestep, t=88.0, dt=1.0
# gusto:INFO at start of timestep, t=89.0, dt=1.0
# gusto:INFO at start of timestep, t=90.0, dt=1.0
# gusto:INFO at start of timestep, t=91.0, dt=1.0
# gusto:INFO at start of timestep, t=92.0, dt=1.0
# gusto:INFO at start of timestep, t=93.0, dt=1.0
# gusto:INFO at start of timestep, t=94.0, dt=1.0
# gusto:INFO at start of timestep, t=95.0, dt=1.0
# gusto:INFO at start of timestep, t=96.0, dt=1.0
# gusto:INFO at start of timestep, t=97.0, dt=1.0
# gusto:INFO at start of timestep, t=98.0, dt=1.0
# gusto:INFO at start of timestep, t=99.0, dt=1.0
# gusto:INFO at start of timestep, t=100.0, dt=1.0
# gusto:INFO at start of timestep, t=101.0, dt=1.0
# gusto:INFO at start of timestep, t=102.0, dt=1.0
# gusto:INFO at start of timestep, t=103.0, dt=1.0
# gusto:INFO at start of timestep, t=104.0, dt=1.0
# gusto:INFO at start of timestep, t=105.0, dt=1.0
# gusto:INFO at start of timestep, t=106.0, dt=1.0
# gusto:INFO at start of timestep, t=107.0, dt=1.0
# gusto:INFO at start of timestep, t=108.0, dt=1.0
# gusto:INFO at start of timestep, t=109.0, dt=1.0
# gusto:INFO at start of timestep, t=110.0, dt=1.0
# gusto:INFO at start of timestep, t=111.0, dt=1.0
# gusto:INFO at start of timestep, t=112.0, dt=1.0
# gusto:INFO at start of timestep, t=113.0, dt=1.0
# gusto:INFO at start of timestep, t=114.0, dt=1.0
# gusto:INFO at start of timestep, t=115.0, dt=1.0
# gusto:INFO at start of timestep, t=116.0, dt=1.0
# gusto:INFO at start of timestep, t=117.0, dt=1.0
# gusto:INFO at start of timestep, t=118.0, dt=1.0
# gusto:INFO at start of timestep, t=119.0, dt=1.0
# gusto:INFO at start of timestep, t=120.0, dt=1.0
# gusto:INFO at start of timestep, t=121.0, dt=1.0
# gusto:INFO at start of timestep, t=122.0, dt=1.0
# gusto:INFO at start of timestep, t=123.0, dt=1.0
# gusto:INFO at start of timestep, t=124.0, dt=1.0
# gusto:INFO at start of timestep, t=125.0, dt=1.0
# gusto:INFO at start of timestep, t=126.0, dt=1.0
# gusto:INFO at start of timestep, t=127.0, dt=1.0
# gusto:INFO at start of timestep, t=128.0, dt=1.0
# gusto:INFO at start of timestep, t=129.0, dt=1.0
# gusto:INFO at start of timestep, t=130.0, dt=1.0
# gusto:INFO at start of timestep, t=131.0, dt=1.0
# gusto:INFO at start of timestep, t=132.0, dt=1.0
# gusto:INFO at start of timestep, t=133.0, dt=1.0
# gusto:INFO at start of timestep, t=134.0, dt=1.0
# gusto:INFO at start of timestep, t=135.0, dt=1.0
# gusto:INFO at start of timestep, t=136.0, dt=1.0
# gusto:INFO at start of timestep, t=137.0, dt=1.0
# gusto:INFO at start of timestep, t=138.0, dt=1.0
# gusto:INFO at start of timestep, t=139.0, dt=1.0
# gusto:INFO at start of timestep, t=140.0, dt=1.0
# gusto:INFO at start of timestep, t=141.0, dt=1.0
# gusto:INFO at start of timestep, t=142.0, dt=1.0
# gusto:INFO at start of timestep, t=143.0, dt=1.0
# gusto:INFO at start of timestep, t=144.0, dt=1.0
# gusto:INFO at start of timestep, t=145.0, dt=1.0
# gusto:INFO at start of timestep, t=146.0, dt=1.0
# gusto:INFO at start of timestep, t=147.0, dt=1.0
# gusto:INFO at start of timestep, t=148.0, dt=1.0
# gusto:INFO at start of timestep, t=149.0, dt=1.0
# gusto:INFO at start of timestep, t=150.0, dt=1.0
# gusto:INFO at start of timestep, t=151.0, dt=1.0
# gusto:INFO at start of timestep, t=152.0, dt=1.0
# gusto:INFO at start of timestep, t=153.0, dt=1.0
# gusto:INFO at start of timestep, t=154.0, dt=1.0
# gusto:INFO at start of timestep, t=155.0, dt=1.0
# gusto:INFO at start of timestep, t=156.0, dt=1.0
# gusto:INFO at start of timestep, t=157.0, dt=1.0
# gusto:INFO at start of timestep, t=158.0, dt=1.0
# gusto:INFO at start of timestep, t=159.0, dt=1.0
# gusto:INFO at start of timestep, t=160.0, dt=1.0
# gusto:INFO at start of timestep, t=161.0, dt=1.0
# gusto:INFO at start of timestep, t=162.0, dt=1.0
# gusto:INFO at start of timestep, t=163.0, dt=1.0
# gusto:INFO at start of timestep, t=164.0, dt=1.0
# gusto:INFO at start of timestep, t=165.0, dt=1.0
# gusto:INFO at start of timestep, t=166.0, dt=1.0
# gusto:INFO at start of timestep, t=167.0, dt=1.0
# gusto:INFO at start of timestep, t=168.0, dt=1.0
# gusto:INFO at start of timestep, t=169.0, dt=1.0
# gusto:INFO at start of timestep, t=170.0, dt=1.0
# gusto:INFO at start of timestep, t=171.0, dt=1.0
# gusto:INFO at start of timestep, t=172.0, dt=1.0
# gusto:INFO at start of timestep, t=173.0, dt=1.0
# gusto:INFO at start of timestep, t=174.0, dt=1.0
# gusto:INFO at start of timestep, t=175.0, dt=1.0
# gusto:INFO at start of timestep, t=176.0, dt=1.0
# gusto:INFO at start of timestep, t=177.0, dt=1.0
# gusto:INFO at start of timestep, t=178.0, dt=1.0
# gusto:INFO at start of timestep, t=179.0, dt=1.0
# gusto:INFO at start of timestep, t=180.0, dt=1.0
# gusto:INFO at start of timestep, t=181.0, dt=1.0
# gusto:INFO at start of timestep, t=182.0, dt=1.0
# gusto:INFO at start of timestep, t=183.0, dt=1.0
# gusto:INFO at start of timestep, t=184.0, dt=1.0
# gusto:INFO at start of timestep, t=185.0, dt=1.0
# gusto:INFO at start of timestep, t=186.0, dt=1.0
# gusto:INFO at start of timestep, t=187.0, dt=1.0
# gusto:INFO at start of timestep, t=188.0, dt=1.0
# gusto:INFO at start of timestep, t=189.0, dt=1.0
# gusto:INFO at start of timestep, t=190.0, dt=1.0
# gusto:INFO at start of timestep, t=191.0, dt=1.0
# gusto:INFO at start of timestep, t=192.0, dt=1.0
# gusto:INFO at start of timestep, t=193.0, dt=1.0
# gusto:INFO at start of timestep, t=194.0, dt=1.0
# gusto:INFO at start of timestep, t=195.0, dt=1.0
# gusto:INFO at start of timestep, t=196.0, dt=1.0
# gusto:INFO at start of timestep, t=197.0, dt=1.0
# gusto:INFO at start of timestep, t=198.0, dt=1.0
# gusto:INFO at start of timestep, t=199.0, dt=1.0
# gusto:INFO at start of timestep, t=200.0, dt=1.0
# gusto:INFO at start of timestep, t=201.0, dt=1.0
# gusto:INFO at start of timestep, t=202.0, dt=1.0
# gusto:INFO at start of timestep, t=203.0, dt=1.0
# gusto:INFO at start of timestep, t=204.0, dt=1.0
# gusto:INFO at start of timestep, t=205.0, dt=1.0
# gusto:INFO at start of timestep, t=206.0, dt=1.0
# gusto:INFO at start of timestep, t=207.0, dt=1.0
# gusto:INFO at start of timestep, t=208.0, dt=1.0
# gusto:INFO at start of timestep, t=209.0, dt=1.0
# gusto:INFO at start of timestep, t=210.0, dt=1.0
# gusto:INFO at start of timestep, t=211.0, dt=1.0
# gusto:INFO at start of timestep, t=212.0, dt=1.0
# gusto:INFO at start of timestep, t=213.0, dt=1.0
# gusto:INFO at start of timestep, t=214.0, dt=1.0
# gusto:INFO at start of timestep, t=215.0, dt=1.0
# gusto:INFO at start of timestep, t=216.0, dt=1.0
# gusto:INFO at start of timestep, t=217.0, dt=1.0
# gusto:INFO at start of timestep, t=218.0, dt=1.0
# gusto:INFO at start of timestep, t=219.0, dt=1.0
# gusto:INFO at start of timestep, t=220.0, dt=1.0
# gusto:INFO at start of timestep, t=221.0, dt=1.0
# gusto:INFO at start of timestep, t=222.0, dt=1.0
# gusto:INFO at start of timestep, t=223.0, dt=1.0
# gusto:INFO at start of timestep, t=224.0, dt=1.0
# gusto:INFO at start of timestep, t=225.0, dt=1.0
# gusto:INFO at start of timestep, t=226.0, dt=1.0
# gusto:INFO at start of timestep, t=227.0, dt=1.0
# gusto:INFO at start of timestep, t=228.0, dt=1.0
# gusto:INFO at start of timestep, t=229.0, dt=1.0
# gusto:INFO at start of timestep, t=230.0, dt=1.0
# gusto:INFO at start of timestep, t=231.0, dt=1.0
# gusto:INFO at start of timestep, t=232.0, dt=1.0
# gusto:INFO at start of timestep, t=233.0, dt=1.0
# gusto:INFO at start of timestep, t=234.0, dt=1.0
# gusto:INFO at start of timestep, t=235.0, dt=1.0
# gusto:INFO at start of timestep, t=236.0, dt=1.0
# gusto:INFO at start of timestep, t=237.0, dt=1.0
# gusto:INFO at start of timestep, t=238.0, dt=1.0
# gusto:INFO at start of timestep, t=239.0, dt=1.0
# gusto:INFO at start of timestep, t=240.0, dt=1.0
# gusto:INFO at start of timestep, t=241.0, dt=1.0
# gusto:INFO at start of timestep, t=242.0, dt=1.0
# gusto:INFO at start of timestep, t=243.0, dt=1.0
# gusto:INFO at start of timestep, t=244.0, dt=1.0
# gusto:INFO at start of timestep, t=245.0, dt=1.0
# gusto:INFO at start of timestep, t=246.0, dt=1.0
# gusto:INFO at start of timestep, t=247.0, dt=1.0
# gusto:INFO at start of timestep, t=248.0, dt=1.0
# gusto:INFO at start of timestep, t=249.0, dt=1.0
# gusto:INFO at start of timestep, t=250.0, dt=1.0
# gusto:INFO at start of timestep, t=251.0, dt=1.0
# gusto:INFO at start of timestep, t=252.0, dt=1.0
# gusto:INFO at start of timestep, t=253.0, dt=1.0
# gusto:INFO at start of timestep, t=254.0, dt=1.0
# gusto:INFO at start of timestep, t=255.0, dt=1.0
# gusto:INFO at start of timestep, t=256.0, dt=1.0
# gusto:INFO at start of timestep, t=257.0, dt=1.0
# gusto:INFO at start of timestep, t=258.0, dt=1.0
# gusto:INFO at start of timestep, t=259.0, dt=1.0
# gusto:INFO at start of timestep, t=260.0, dt=1.0
# gusto:INFO at start of timestep, t=261.0, dt=1.0
# gusto:INFO at start of timestep, t=262.0, dt=1.0
# gusto:INFO at start of timestep, t=263.0, dt=1.0
# gusto:INFO at start of timestep, t=264.0, dt=1.0
# gusto:INFO at start of timestep, t=265.0, dt=1.0
# gusto:INFO at start of timestep, t=266.0, dt=1.0
# gusto:INFO at start of timestep, t=267.0, dt=1.0
# gusto:INFO at start of timestep, t=268.0, dt=1.0
# gusto:INFO at start of timestep, t=269.0, dt=1.0
# gusto:INFO at start of timestep, t=270.0, dt=1.0
# gusto:INFO at start of timestep, t=271.0, dt=1.0
# gusto:INFO at start of timestep, t=272.0, dt=1.0
# gusto:INFO at start of timestep, t=273.0, dt=1.0
# gusto:INFO at start of timestep, t=274.0, dt=1.0
# gusto:INFO at start of timestep, t=275.0, dt=1.0
# gusto:INFO at start of timestep, t=276.0, dt=1.0
# gusto:INFO at start of timestep, t=277.0, dt=1.0
# gusto:INFO at start of timestep, t=278.0, dt=1.0
# gusto:INFO at start of timestep, t=279.0, dt=1.0
# gusto:INFO at start of timestep, t=280.0, dt=1.0
# gusto:INFO at start of timestep, t=281.0, dt=1.0
# gusto:INFO at start of timestep, t=282.0, dt=1.0
# gusto:INFO at start of timestep, t=283.0, dt=1.0
# gusto:INFO at start of timestep, t=284.0, dt=1.0
# gusto:INFO at start of timestep, t=285.0, dt=1.0
# gusto:INFO at start of timestep, t=286.0, dt=1.0
# gusto:INFO at start of timestep, t=287.0, dt=1.0
# gusto:INFO at start of timestep, t=288.0, dt=1.0
# gusto:INFO at start of timestep, t=289.0, dt=1.0
# gusto:INFO at start of timestep, t=290.0, dt=1.0
# gusto:INFO at start of timestep, t=291.0, dt=1.0
# gusto:INFO at start of timestep, t=292.0, dt=1.0
# gusto:INFO at start of timestep, t=293.0, dt=1.0
# gusto:INFO at start of timestep, t=294.0, dt=1.0
# gusto:INFO at start of timestep, t=295.0, dt=1.0
# gusto:INFO at start of timestep, t=296.0, dt=1.0
# gusto:INFO at start of timestep, t=297.0, dt=1.0
# gusto:INFO at start of timestep, t=298.0, dt=1.0
# gusto:INFO at start of timestep, t=299.0, dt=1.0
# gusto:INFO at start of timestep, t=300.0, dt=1.0
# gusto:INFO at start of timestep, t=301.0, dt=1.0
# gusto:INFO at start of timestep, t=302.0, dt=1.0
# gusto:INFO at start of timestep, t=303.0, dt=1.0
# gusto:INFO at start of timestep, t=304.0, dt=1.0
# gusto:INFO at start of timestep, t=305.0, dt=1.0
# gusto:INFO at start of timestep, t=306.0, dt=1.0
# gusto:INFO at start of timestep, t=307.0, dt=1.0
# gusto:INFO at start of timestep, t=308.0, dt=1.0
# gusto:INFO at start of timestep, t=309.0, dt=1.0
# gusto:INFO at start of timestep, t=310.0, dt=1.0
# gusto:INFO at start of timestep, t=311.0, dt=1.0
# gusto:INFO at start of timestep, t=312.0, dt=1.0
# gusto:INFO at start of timestep, t=313.0, dt=1.0
# gusto:INFO at start of timestep, t=314.0, dt=1.0
# gusto:INFO at start of timestep, t=315.0, dt=1.0
# gusto:INFO at start of timestep, t=316.0, dt=1.0
# gusto:INFO at start of timestep, t=317.0, dt=1.0
# gusto:INFO at start of timestep, t=318.0, dt=1.0
# gusto:INFO at start of timestep, t=319.0, dt=1.0
# gusto:INFO at start of timestep, t=320.0, dt=1.0
# gusto:INFO at start of timestep, t=321.0, dt=1.0
# gusto:INFO at start of timestep, t=322.0, dt=1.0
# gusto:INFO at start of timestep, t=323.0, dt=1.0
# gusto:INFO at start of timestep, t=324.0, dt=1.0
# gusto:INFO at start of timestep, t=325.0, dt=1.0
# gusto:INFO at start of timestep, t=326.0, dt=1.0
# gusto:INFO at start of timestep, t=327.0, dt=1.0
# gusto:INFO at start of timestep, t=328.0, dt=1.0
# gusto:INFO at start of timestep, t=329.0, dt=1.0
# gusto:INFO at start of timestep, t=330.0, dt=1.0
# gusto:INFO at start of timestep, t=331.0, dt=1.0
# gusto:INFO at start of timestep, t=332.0, dt=1.0
# gusto:INFO at start of timestep, t=333.0, dt=1.0
# gusto:INFO at start of timestep, t=334.0, dt=1.0
# gusto:INFO at start of timestep, t=335.0, dt=1.0
# gusto:INFO at start of timestep, t=336.0, dt=1.0
# gusto:INFO at start of timestep, t=337.0, dt=1.0
# gusto:INFO at start of timestep, t=338.0, dt=1.0
# gusto:INFO at start of timestep, t=339.0, dt=1.0
# gusto:INFO at start of timestep, t=340.0, dt=1.0
# gusto:INFO at start of timestep, t=341.0, dt=1.0
# gusto:INFO at start of timestep, t=342.0, dt=1.0
# gusto:INFO at start of timestep, t=343.0, dt=1.0
# gusto:INFO at start of timestep, t=344.0, dt=1.0
# gusto:INFO at start of timestep, t=345.0, dt=1.0
# gusto:INFO at start of timestep, t=346.0, dt=1.0
# gusto:INFO at start of timestep, t=347.0, dt=1.0
# gusto:INFO at start of timestep, t=348.0, dt=1.0
# gusto:INFO at start of timestep, t=349.0, dt=1.0
# gusto:INFO at start of timestep, t=350.0, dt=1.0
# gusto:INFO at start of timestep, t=351.0, dt=1.0
# gusto:INFO at start of timestep, t=352.0, dt=1.0
# gusto:INFO at start of timestep, t=353.0, dt=1.0
# gusto:INFO at start of timestep, t=354.0, dt=1.0
# gusto:INFO at start of timestep, t=355.0, dt=1.0
# gusto:INFO at start of timestep, t=356.0, dt=1.0
# gusto:INFO at start of timestep, t=357.0, dt=1.0
# gusto:INFO at start of timestep, t=358.0, dt=1.0
# gusto:INFO at start of timestep, t=359.0, dt=1.0
# gusto:INFO at start of timestep, t=360.0, dt=1.0
# gusto:INFO at start of timestep, t=361.0, dt=1.0
# gusto:INFO at start of timestep, t=362.0, dt=1.0
# gusto:INFO at start of timestep, t=363.0, dt=1.0
# gusto:INFO at start of timestep, t=364.0, dt=1.0
# gusto:INFO at start of timestep, t=365.0, dt=1.0
# gusto:INFO at start of timestep, t=366.0, dt=1.0
# gusto:INFO at start of timestep, t=367.0, dt=1.0
# gusto:INFO at start of timestep, t=368.0, dt=1.0
# gusto:INFO at start of timestep, t=369.0, dt=1.0
# gusto:INFO at start of timestep, t=370.0, dt=1.0
# gusto:INFO at start of timestep, t=371.0, dt=1.0
# gusto:INFO at start of timestep, t=372.0, dt=1.0
# gusto:INFO at start of timestep, t=373.0, dt=1.0
# gusto:INFO at start of timestep, t=374.0, dt=1.0
# gusto:INFO at start of timestep, t=375.0, dt=1.0
# gusto:INFO at start of timestep, t=376.0, dt=1.0
# gusto:INFO at start of timestep, t=377.0, dt=1.0
# gusto:INFO at start of timestep, t=378.0, dt=1.0
# gusto:INFO at start of timestep, t=379.0, dt=1.0
# gusto:INFO at start of timestep, t=380.0, dt=1.0
# gusto:INFO at start of timestep, t=381.0, dt=1.0
# gusto:INFO at start of timestep, t=382.0, dt=1.0
# gusto:INFO at start of timestep, t=383.0, dt=1.0
# gusto:INFO at start of timestep, t=384.0, dt=1.0
# gusto:INFO at start of timestep, t=385.0, dt=1.0
# gusto:INFO at start of timestep, t=386.0, dt=1.0
# gusto:INFO at start of timestep, t=387.0, dt=1.0
# gusto:INFO at start of timestep, t=388.0, dt=1.0
# gusto:INFO at start of timestep, t=389.0, dt=1.0
# gusto:INFO at start of timestep, t=390.0, dt=1.0
# gusto:INFO at start of timestep, t=391.0, dt=1.0
# gusto:INFO at start of timestep, t=392.0, dt=1.0
# gusto:INFO at start of timestep, t=393.0, dt=1.0
# gusto:INFO at start of timestep, t=394.0, dt=1.0
# gusto:INFO at start of timestep, t=395.0, dt=1.0
# gusto:INFO at start of timestep, t=396.0, dt=1.0
# gusto:INFO at start of timestep, t=397.0, dt=1.0
# gusto:INFO at start of timestep, t=398.0, dt=1.0
# gusto:INFO at start of timestep, t=399.0, dt=1.0
# gusto:INFO at start of timestep, t=400.0, dt=1.0
# gusto:INFO at start of timestep, t=401.0, dt=1.0
# gusto:INFO at start of timestep, t=402.0, dt=1.0
# gusto:INFO at start of timestep, t=403.0, dt=1.0
# gusto:INFO at start of timestep, t=404.0, dt=1.0
# gusto:INFO at start of timestep, t=405.0, dt=1.0
# gusto:INFO at start of timestep, t=406.0, dt=1.0
# gusto:INFO at start of timestep, t=407.0, dt=1.0
# gusto:INFO at start of timestep, t=408.0, dt=1.0
# gusto:INFO at start of timestep, t=409.0, dt=1.0
# gusto:INFO at start of timestep, t=410.0, dt=1.0
# gusto:INFO at start of timestep, t=411.0, dt=1.0
# gusto:INFO at start of timestep, t=412.0, dt=1.0
# gusto:INFO at start of timestep, t=413.0, dt=1.0
# gusto:INFO at start of timestep, t=414.0, dt=1.0
# gusto:INFO at start of timestep, t=415.0, dt=1.0
# gusto:INFO at start of timestep, t=416.0, dt=1.0
# gusto:INFO at start of timestep, t=417.0, dt=1.0
# gusto:INFO at start of timestep, t=418.0, dt=1.0
# gusto:INFO at start of timestep, t=419.0, dt=1.0
# gusto:INFO at start of timestep, t=420.0, dt=1.0
# gusto:INFO at start of timestep, t=421.0, dt=1.0
# gusto:INFO at start of timestep, t=422.0, dt=1.0
# gusto:INFO at start of timestep, t=423.0, dt=1.0
# gusto:INFO at start of timestep, t=424.0, dt=1.0
# gusto:INFO at start of timestep, t=425.0, dt=1.0
# gusto:INFO at start of timestep, t=426.0, dt=1.0
# gusto:INFO at start of timestep, t=427.0, dt=1.0
# gusto:INFO at start of timestep, t=428.0, dt=1.0
# gusto:INFO at start of timestep, t=429.0, dt=1.0
# gusto:INFO at start of timestep, t=430.0, dt=1.0
# gusto:INFO at start of timestep, t=431.0, dt=1.0
# gusto:INFO at start of timestep, t=432.0, dt=1.0
# gusto:INFO at start of timestep, t=433.0, dt=1.0
# gusto:INFO at start of timestep, t=434.0, dt=1.0
# gusto:INFO at start of timestep, t=435.0, dt=1.0
# gusto:INFO at start of timestep, t=436.0, dt=1.0
# gusto:INFO at start of timestep, t=437.0, dt=1.0
# gusto:INFO at start of timestep, t=438.0, dt=1.0
# gusto:INFO at start of timestep, t=439.0, dt=1.0
# gusto:INFO at start of timestep, t=440.0, dt=1.0
# gusto:INFO at start of timestep, t=441.0, dt=1.0
# gusto:INFO at start of timestep, t=442.0, dt=1.0
# gusto:INFO at start of timestep, t=443.0, dt=1.0
# gusto:INFO at start of timestep, t=444.0, dt=1.0
# gusto:INFO at start of timestep, t=445.0, dt=1.0
# gusto:INFO at start of timestep, t=446.0, dt=1.0
# gusto:INFO at start of timestep, t=447.0, dt=1.0
# gusto:INFO at start of timestep, t=448.0, dt=1.0
# gusto:INFO at start of timestep, t=449.0, dt=1.0
# gusto:INFO at start of timestep, t=450.0, dt=1.0
# gusto:INFO at start of timestep, t=451.0, dt=1.0
# gusto:INFO at start of timestep, t=452.0, dt=1.0
# gusto:INFO at start of timestep, t=453.0, dt=1.0
# gusto:INFO at start of timestep, t=454.0, dt=1.0
# gusto:INFO at start of timestep, t=455.0, dt=1.0
# gusto:INFO at start of timestep, t=456.0, dt=1.0
# gusto:INFO at start of timestep, t=457.0, dt=1.0
# gusto:INFO at start of timestep, t=458.0, dt=1.0
# gusto:INFO at start of timestep, t=459.0, dt=1.0
# gusto:INFO at start of timestep, t=460.0, dt=1.0
# gusto:INFO at start of timestep, t=461.0, dt=1.0
# gusto:INFO at start of timestep, t=462.0, dt=1.0
# gusto:INFO at start of timestep, t=463.0, dt=1.0
# gusto:INFO at start of timestep, t=464.0, dt=1.0
# gusto:INFO at start of timestep, t=465.0, dt=1.0
# gusto:INFO at start of timestep, t=466.0, dt=1.0
# gusto:INFO at start of timestep, t=467.0, dt=1.0
# gusto:INFO at start of timestep, t=468.0, dt=1.0
# gusto:INFO at start of timestep, t=469.0, dt=1.0
# gusto:INFO at start of timestep, t=470.0, dt=1.0
# gusto:INFO at start of timestep, t=471.0, dt=1.0
# gusto:INFO at start of timestep, t=472.0, dt=1.0
# gusto:INFO at start of timestep, t=473.0, dt=1.0
# gusto:INFO at start of timestep, t=474.0, dt=1.0
# gusto:INFO at start of timestep, t=475.0, dt=1.0
# gusto:INFO at start of timestep, t=476.0, dt=1.0
# gusto:INFO at start of timestep, t=477.0, dt=1.0
# gusto:INFO at start of timestep, t=478.0, dt=1.0
# gusto:INFO at start of timestep, t=479.0, dt=1.0
# gusto:INFO at start of timestep, t=480.0, dt=1.0
# gusto:INFO at start of timestep, t=481.0, dt=1.0
# gusto:INFO at start of timestep, t=482.0, dt=1.0
# gusto:INFO at start of timestep, t=483.0, dt=1.0
# gusto:INFO at start of timestep, t=484.0, dt=1.0
# gusto:INFO at start of timestep, t=485.0, dt=1.0
# gusto:INFO at start of timestep, t=486.0, dt=1.0
# gusto:INFO at start of timestep, t=487.0, dt=1.0
# gusto:INFO at start of timestep, t=488.0, dt=1.0
# gusto:INFO at start of timestep, t=489.0, dt=1.0
# gusto:INFO at start of timestep, t=490.0, dt=1.0
# gusto:INFO at start of timestep, t=491.0, dt=1.0
# gusto:INFO at start of timestep, t=492.0, dt=1.0
# gusto:INFO at start of timestep, t=493.0, dt=1.0
# gusto:INFO at start of timestep, t=494.0, dt=1.0
# gusto:INFO at start of timestep, t=495.0, dt=1.0
# gusto:INFO at start of timestep, t=496.0, dt=1.0
# gusto:INFO at start of timestep, t=497.0, dt=1.0
# gusto:INFO at start of timestep, t=498.0, dt=1.0
# gusto:INFO at start of timestep, t=499.0, dt=1.0
# gusto:INFO at start of timestep, t=500.0, dt=1.0
# gusto:INFO at start of timestep, t=501.0, dt=1.0
# gusto:INFO at start of timestep, t=502.0, dt=1.0
# gusto:INFO at start of timestep, t=503.0, dt=1.0
# gusto:INFO at start of timestep, t=504.0, dt=1.0
# gusto:INFO at start of timestep, t=505.0, dt=1.0
# gusto:INFO at start of timestep, t=506.0, dt=1.0
# gusto:INFO at start of timestep, t=507.0, dt=1.0
# gusto:INFO at start of timestep, t=508.0, dt=1.0
# gusto:INFO at start of timestep, t=509.0, dt=1.0
# gusto:INFO at start of timestep, t=510.0, dt=1.0
# gusto:INFO at start of timestep, t=511.0, dt=1.0
# gusto:INFO at start of timestep, t=512.0, dt=1.0
# gusto:INFO at start of timestep, t=513.0, dt=1.0
# gusto:INFO at start of timestep, t=514.0, dt=1.0
# gusto:INFO at start of timestep, t=515.0, dt=1.0
# gusto:INFO at start of timestep, t=516.0, dt=1.0
# gusto:INFO at start of timestep, t=517.0, dt=1.0
# gusto:INFO at start of timestep, t=518.0, dt=1.0
# gusto:INFO at start of timestep, t=519.0, dt=1.0
# gusto:INFO at start of timestep, t=520.0, dt=1.0
# gusto:INFO at start of timestep, t=521.0, dt=1.0
# gusto:INFO at start of timestep, t=522.0, dt=1.0
# gusto:INFO at start of timestep, t=523.0, dt=1.0
# gusto:INFO at start of timestep, t=524.0, dt=1.0
# gusto:INFO at start of timestep, t=525.0, dt=1.0
# gusto:INFO at start of timestep, t=526.0, dt=1.0
# gusto:INFO at start of timestep, t=527.0, dt=1.0
# gusto:INFO at start of timestep, t=528.0, dt=1.0
# gusto:INFO at start of timestep, t=529.0, dt=1.0
# gusto:INFO at start of timestep, t=530.0, dt=1.0
# gusto:INFO at start of timestep, t=531.0, dt=1.0
# gusto:INFO at start of timestep, t=532.0, dt=1.0
# gusto:INFO at start of timestep, t=533.0, dt=1.0
# gusto:INFO at start of timestep, t=534.0, dt=1.0
# gusto:INFO at start of timestep, t=535.0, dt=1.0
# gusto:INFO at start of timestep, t=536.0, dt=1.0
# gusto:INFO at start of timestep, t=537.0, dt=1.0
# gusto:INFO at start of timestep, t=538.0, dt=1.0
# gusto:INFO at start of timestep, t=539.0, dt=1.0
# gusto:INFO at start of timestep, t=540.0, dt=1.0
# gusto:INFO at start of timestep, t=541.0, dt=1.0
# gusto:INFO at start of timestep, t=542.0, dt=1.0
# gusto:INFO at start of timestep, t=543.0, dt=1.0
# gusto:INFO at start of timestep, t=544.0, dt=1.0
# gusto:INFO at start of timestep, t=545.0, dt=1.0
# gusto:INFO at start of timestep, t=546.0, dt=1.0
# gusto:INFO at start of timestep, t=547.0, dt=1.0
# gusto:INFO at start of timestep, t=548.0, dt=1.0
# gusto:INFO at start of timestep, t=549.0, dt=1.0
# gusto:INFO at start of timestep, t=550.0, dt=1.0
# gusto:INFO at start of timestep, t=551.0, dt=1.0
# gusto:INFO at start of timestep, t=552.0, dt=1.0
# gusto:INFO at start of timestep, t=553.0, dt=1.0
# gusto:INFO at start of timestep, t=554.0, dt=1.0
# gusto:INFO at start of timestep, t=555.0, dt=1.0
# gusto:INFO at start of timestep, t=556.0, dt=1.0
# gusto:INFO at start of timestep, t=557.0, dt=1.0
# gusto:INFO at start of timestep, t=558.0, dt=1.0
# gusto:INFO at start of timestep, t=559.0, dt=1.0
# gusto:INFO at start of timestep, t=560.0, dt=1.0
# gusto:INFO at start of timestep, t=561.0, dt=1.0
# gusto:INFO at start of timestep, t=562.0, dt=1.0
# gusto:INFO at start of timestep, t=563.0, dt=1.0
# gusto:INFO at start of timestep, t=564.0, dt=1.0
# gusto:INFO at start of timestep, t=565.0, dt=1.0
# gusto:INFO at start of timestep, t=566.0, dt=1.0
# gusto:INFO at start of timestep, t=567.0, dt=1.0
# gusto:INFO at start of timestep, t=568.0, dt=1.0
# gusto:INFO at start of timestep, t=569.0, dt=1.0
# gusto:INFO at start of timestep, t=570.0, dt=1.0
# gusto:INFO at start of timestep, t=571.0, dt=1.0
# gusto:INFO at start of timestep, t=572.0, dt=1.0
# gusto:INFO at start of timestep, t=573.0, dt=1.0
# gusto:INFO at start of timestep, t=574.0, dt=1.0
# gusto:INFO at start of timestep, t=575.0, dt=1.0
# gusto:INFO at start of timestep, t=576.0, dt=1.0
# gusto:INFO at start of timestep, t=577.0, dt=1.0
# gusto:INFO at start of timestep, t=578.0, dt=1.0
# gusto:INFO at start of timestep, t=579.0, dt=1.0
# gusto:INFO at start of timestep, t=580.0, dt=1.0
# gusto:INFO at start of timestep, t=581.0, dt=1.0
# gusto:INFO at start of timestep, t=582.0, dt=1.0
# gusto:INFO at start of timestep, t=583.0, dt=1.0
# gusto:INFO at start of timestep, t=584.0, dt=1.0
# gusto:INFO at start of timestep, t=585.0, dt=1.0
# gusto:INFO at start of timestep, t=586.0, dt=1.0
# gusto:INFO at start of timestep, t=587.0, dt=1.0
# gusto:INFO at start of timestep, t=588.0, dt=1.0
# gusto:INFO at start of timestep, t=589.0, dt=1.0
# gusto:INFO at start of timestep, t=590.0, dt=1.0
# gusto:INFO at start of timestep, t=591.0, dt=1.0
# gusto:INFO at start of timestep, t=592.0, dt=1.0
# gusto:INFO at start of timestep, t=593.0, dt=1.0
# gusto:INFO at start of timestep, t=594.0, dt=1.0
# gusto:INFO at start of timestep, t=595.0, dt=1.0
# gusto:INFO at start of timestep, t=596.0, dt=1.0
# gusto:INFO at start of timestep, t=597.0, dt=1.0
# gusto:INFO at start of timestep, t=598.0, dt=1.0
# gusto:INFO at start of timestep, t=599.0, dt=1.0
# gusto:INFO at start of timestep, t=600.0, dt=1.0
# gusto:INFO at start of timestep, t=601.0, dt=1.0
# gusto:INFO at start of timestep, t=602.0, dt=1.0
# gusto:INFO at start of timestep, t=603.0, dt=1.0
# gusto:INFO at start of timestep, t=604.0, dt=1.0
# gusto:INFO at start of timestep, t=605.0, dt=1.0
# gusto:INFO at start of timestep, t=606.0, dt=1.0
# gusto:INFO at start of timestep, t=607.0, dt=1.0
# gusto:INFO at start of timestep, t=608.0, dt=1.0
# gusto:INFO at start of timestep, t=609.0, dt=1.0
# gusto:INFO at start of timestep, t=610.0, dt=1.0
# gusto:INFO at start of timestep, t=611.0, dt=1.0
# gusto:INFO at start of timestep, t=612.0, dt=1.0
# gusto:INFO at start of timestep, t=613.0, dt=1.0
# gusto:INFO at start of timestep, t=614.0, dt=1.0
# gusto:INFO at start of timestep, t=615.0, dt=1.0
# gusto:INFO at start of timestep, t=616.0, dt=1.0
# gusto:INFO at start of timestep, t=617.0, dt=1.0
# gusto:INFO at start of timestep, t=618.0, dt=1.0
# gusto:INFO at start of timestep, t=619.0, dt=1.0
# gusto:INFO at start of timestep, t=620.0, dt=1.0
# gusto:INFO at start of timestep, t=621.0, dt=1.0
# gusto:INFO at start of timestep, t=622.0, dt=1.0
# gusto:INFO at start of timestep, t=623.0, dt=1.0
# gusto:INFO at start of timestep, t=624.0, dt=1.0
# gusto:INFO at start of timestep, t=625.0, dt=1.0
# gusto:INFO at start of timestep, t=626.0, dt=1.0
# gusto:INFO at start of timestep, t=627.0, dt=1.0
# gusto:INFO at start of timestep, t=628.0, dt=1.0
# gusto:INFO at start of timestep, t=629.0, dt=1.0
# gusto:INFO at start of timestep, t=630.0, dt=1.0
# gusto:INFO at start of timestep, t=631.0, dt=1.0
# gusto:INFO at start of timestep, t=632.0, dt=1.0
# gusto:INFO at start of timestep, t=633.0, dt=1.0
# gusto:INFO at start of timestep, t=634.0, dt=1.0
# gusto:INFO at start of timestep, t=635.0, dt=1.0
# gusto:INFO at start of timestep, t=636.0, dt=1.0
# gusto:INFO at start of timestep, t=637.0, dt=1.0
# gusto:INFO at start of timestep, t=638.0, dt=1.0
# gusto:INFO at start of timestep, t=639.0, dt=1.0
# gusto:INFO at start of timestep, t=640.0, dt=1.0
# gusto:INFO at start of timestep, t=641.0, dt=1.0
# gusto:INFO at start of timestep, t=642.0, dt=1.0
# gusto:INFO at start of timestep, t=643.0, dt=1.0
# gusto:INFO at start of timestep, t=644.0, dt=1.0
# gusto:INFO at start of timestep, t=645.0, dt=1.0
# gusto:INFO at start of timestep, t=646.0, dt=1.0
# gusto:INFO at start of timestep, t=647.0, dt=1.0
# gusto:INFO at start of timestep, t=648.0, dt=1.0
# gusto:INFO at start of timestep, t=649.0, dt=1.0
# gusto:INFO at start of timestep, t=650.0, dt=1.0
# gusto:INFO at start of timestep, t=651.0, dt=1.0
# gusto:INFO at start of timestep, t=652.0, dt=1.0
# gusto:INFO at start of timestep, t=653.0, dt=1.0
# gusto:INFO at start of timestep, t=654.0, dt=1.0
# gusto:INFO at start of timestep, t=655.0, dt=1.0
# gusto:INFO at start of timestep, t=656.0, dt=1.0
# gusto:INFO at start of timestep, t=657.0, dt=1.0
# gusto:INFO at start of timestep, t=658.0, dt=1.0
# gusto:INFO at start of timestep, t=659.0, dt=1.0
# gusto:INFO at start of timestep, t=660.0, dt=1.0
# gusto:INFO at start of timestep, t=661.0, dt=1.0
# gusto:INFO at start of timestep, t=662.0, dt=1.0
# gusto:INFO at start of timestep, t=663.0, dt=1.0
# gusto:INFO at start of timestep, t=664.0, dt=1.0
# gusto:INFO at start of timestep, t=665.0, dt=1.0
# gusto:INFO at start of timestep, t=666.0, dt=1.0
# gusto:INFO at start of timestep, t=667.0, dt=1.0
# gusto:INFO at start of timestep, t=668.0, dt=1.0
# gusto:INFO at start of timestep, t=669.0, dt=1.0
# gusto:INFO at start of timestep, t=670.0, dt=1.0
# gusto:INFO at start of timestep, t=671.0, dt=1.0
# gusto:INFO at start of timestep, t=672.0, dt=1.0
# gusto:INFO at start of timestep, t=673.0, dt=1.0
# gusto:INFO at start of timestep, t=674.0, dt=1.0
# gusto:INFO at start of timestep, t=675.0, dt=1.0
# gusto:INFO at start of timestep, t=676.0, dt=1.0
# gusto:INFO at start of timestep, t=677.0, dt=1.0
# gusto:INFO at start of timestep, t=678.0, dt=1.0
# gusto:INFO at start of timestep, t=679.0, dt=1.0
# gusto:INFO at start of timestep, t=680.0, dt=1.0
# gusto:INFO at start of timestep, t=681.0, dt=1.0
# gusto:INFO at start of timestep, t=682.0, dt=1.0
# gusto:INFO at start of timestep, t=683.0, dt=1.0
# gusto:INFO at start of timestep, t=684.0, dt=1.0
# gusto:INFO at start of timestep, t=685.0, dt=1.0
# gusto:INFO at start of timestep, t=686.0, dt=1.0
# gusto:INFO at start of timestep, t=687.0, dt=1.0
# gusto:INFO at start of timestep, t=688.0, dt=1.0
# gusto:INFO at start of timestep, t=689.0, dt=1.0
# gusto:INFO at start of timestep, t=690.0, dt=1.0
# gusto:INFO at start of timestep, t=691.0, dt=1.0
# gusto:INFO at start of timestep, t=692.0, dt=1.0
# gusto:INFO at start of timestep, t=693.0, dt=1.0
# gusto:INFO at start of timestep, t=694.0, dt=1.0
# gusto:INFO at start of timestep, t=695.0, dt=1.0
# gusto:INFO at start of timestep, t=696.0, dt=1.0
# gusto:INFO at start of timestep, t=697.0, dt=1.0
# gusto:INFO at start of timestep, t=698.0, dt=1.0
# gusto:INFO at start of timestep, t=699.0, dt=1.0
# gusto:INFO at start of timestep, t=700.0, dt=1.0
# gusto:INFO at start of timestep, t=701.0, dt=1.0
# gusto:INFO at start of timestep, t=702.0, dt=1.0
# gusto:INFO at start of timestep, t=703.0, dt=1.0
# gusto:INFO at start of timestep, t=704.0, dt=1.0
# gusto:INFO at start of timestep, t=705.0, dt=1.0
# gusto:INFO at start of timestep, t=706.0, dt=1.0
# gusto:INFO at start of timestep, t=707.0, dt=1.0
# gusto:INFO at start of timestep, t=708.0, dt=1.0
# gusto:INFO at start of timestep, t=709.0, dt=1.0
# gusto:INFO at start of timestep, t=710.0, dt=1.0
# gusto:INFO at start of timestep, t=711.0, dt=1.0
# gusto:INFO at start of timestep, t=712.0, dt=1.0
# gusto:INFO at start of timestep, t=713.0, dt=1.0
# gusto:INFO at start of timestep, t=714.0, dt=1.0
# gusto:INFO at start of timestep, t=715.0, dt=1.0
# gusto:INFO at start of timestep, t=716.0, dt=1.0
# gusto:INFO at start of timestep, t=717.0, dt=1.0
# gusto:INFO at start of timestep, t=718.0, dt=1.0
# gusto:INFO at start of timestep, t=719.0, dt=1.0
# gusto:INFO at start of timestep, t=720.0, dt=1.0
# gusto:INFO at start of timestep, t=721.0, dt=1.0
# gusto:INFO at start of timestep, t=722.0, dt=1.0
# gusto:INFO at start of timestep, t=723.0, dt=1.0
# gusto:INFO at start of timestep, t=724.0, dt=1.0
# gusto:INFO at start of timestep, t=725.0, dt=1.0
# gusto:INFO at start of timestep, t=726.0, dt=1.0
# gusto:INFO at start of timestep, t=727.0, dt=1.0
# gusto:INFO at start of timestep, t=728.0, dt=1.0
# gusto:INFO at start of timestep, t=729.0, dt=1.0
# gusto:INFO at start of timestep, t=730.0, dt=1.0
# gusto:INFO at start of timestep, t=731.0, dt=1.0
# gusto:INFO at start of timestep, t=732.0, dt=1.0
# gusto:INFO at start of timestep, t=733.0, dt=1.0
# gusto:INFO at start of timestep, t=734.0, dt=1.0
# gusto:INFO at start of timestep, t=735.0, dt=1.0
# gusto:INFO at start of timestep, t=736.0, dt=1.0
# gusto:INFO at start of timestep, t=737.0, dt=1.0
# gusto:INFO at start of timestep, t=738.0, dt=1.0
# gusto:INFO at start of timestep, t=739.0, dt=1.0
# gusto:INFO at start of timestep, t=740.0, dt=1.0
# gusto:INFO at start of timestep, t=741.0, dt=1.0
# gusto:INFO at start of timestep, t=742.0, dt=1.0
# gusto:INFO at start of timestep, t=743.0, dt=1.0
# gusto:INFO at start of timestep, t=744.0, dt=1.0
# gusto:INFO at start of timestep, t=745.0, dt=1.0
# gusto:INFO at start of timestep, t=746.0, dt=1.0
# gusto:INFO at start of timestep, t=747.0, dt=1.0
# gusto:INFO at start of timestep, t=748.0, dt=1.0
# gusto:INFO at start of timestep, t=749.0, dt=1.0
# gusto:INFO at start of timestep, t=750.0, dt=1.0
# gusto:INFO at start of timestep, t=751.0, dt=1.0
# gusto:INFO at start of timestep, t=752.0, dt=1.0
# gusto:INFO at start of timestep, t=753.0, dt=1.0
# gusto:INFO at start of timestep, t=754.0, dt=1.0
# gusto:INFO at start of timestep, t=755.0, dt=1.0
# gusto:INFO at start of timestep, t=756.0, dt=1.0
# gusto:INFO at start of timestep, t=757.0, dt=1.0
# gusto:INFO at start of timestep, t=758.0, dt=1.0
# gusto:INFO at start of timestep, t=759.0, dt=1.0
# gusto:INFO at start of timestep, t=760.0, dt=1.0
# gusto:INFO at start of timestep, t=761.0, dt=1.0
# gusto:INFO at start of timestep, t=762.0, dt=1.0
# gusto:INFO at start of timestep, t=763.0, dt=1.0
# gusto:INFO at start of timestep, t=764.0, dt=1.0
# gusto:INFO at start of timestep, t=765.0, dt=1.0
# gusto:INFO at start of timestep, t=766.0, dt=1.0
# gusto:INFO at start of timestep, t=767.0, dt=1.0
# gusto:INFO at start of timestep, t=768.0, dt=1.0
# gusto:INFO at start of timestep, t=769.0, dt=1.0
# gusto:INFO at start of timestep, t=770.0, dt=1.0
# gusto:INFO at start of timestep, t=771.0, dt=1.0
# gusto:INFO at start of timestep, t=772.0, dt=1.0
# gusto:INFO at start of timestep, t=773.0, dt=1.0
# gusto:INFO at start of timestep, t=774.0, dt=1.0
# gusto:INFO at start of timestep, t=775.0, dt=1.0
# gusto:INFO at start of timestep, t=776.0, dt=1.0
# gusto:INFO at start of timestep, t=777.0, dt=1.0
# gusto:INFO at start of timestep, t=778.0, dt=1.0
# gusto:INFO at start of timestep, t=779.0, dt=1.0
# gusto:INFO at start of timestep, t=780.0, dt=1.0
# gusto:INFO at start of timestep, t=781.0, dt=1.0
# gusto:INFO at start of timestep, t=782.0, dt=1.0
# gusto:INFO at start of timestep, t=783.0, dt=1.0
# gusto:INFO at start of timestep, t=784.0, dt=1.0
# gusto:INFO at start of timestep, t=785.0, dt=1.0
# gusto:INFO at start of timestep, t=786.0, dt=1.0
# gusto:INFO at start of timestep, t=787.0, dt=1.0
# gusto:INFO at start of timestep, t=788.0, dt=1.0
# gusto:INFO at start of timestep, t=789.0, dt=1.0
# gusto:INFO at start of timestep, t=790.0, dt=1.0
# gusto:INFO at start of timestep, t=791.0, dt=1.0
# gusto:INFO at start of timestep, t=792.0, dt=1.0
# gusto:INFO at start of timestep, t=793.0, dt=1.0
# gusto:INFO at start of timestep, t=794.0, dt=1.0
# gusto:INFO at start of timestep, t=795.0, dt=1.0
# gusto:INFO at start of timestep, t=796.0, dt=1.0
# gusto:INFO at start of timestep, t=797.0, dt=1.0
# gusto:INFO at start of timestep, t=798.0, dt=1.0
# gusto:INFO at start of timestep, t=799.0, dt=1.0
# gusto:INFO at start of timestep, t=800.0, dt=1.0
# gusto:INFO at start of timestep, t=801.0, dt=1.0
# gusto:INFO at start of timestep, t=802.0, dt=1.0
# gusto:INFO at start of timestep, t=803.0, dt=1.0
# gusto:INFO at start of timestep, t=804.0, dt=1.0
# gusto:INFO at start of timestep, t=805.0, dt=1.0
# gusto:INFO at start of timestep, t=806.0, dt=1.0
# gusto:INFO at start of timestep, t=807.0, dt=1.0
# gusto:INFO at start of timestep, t=808.0, dt=1.0
# gusto:INFO at start of timestep, t=809.0, dt=1.0
# gusto:INFO at start of timestep, t=810.0, dt=1.0
# gusto:INFO at start of timestep, t=811.0, dt=1.0
# gusto:INFO at start of timestep, t=812.0, dt=1.0
# gusto:INFO at start of timestep, t=813.0, dt=1.0
# gusto:INFO at start of timestep, t=814.0, dt=1.0
# gusto:INFO at start of timestep, t=815.0, dt=1.0
# gusto:INFO at start of timestep, t=816.0, dt=1.0
# gusto:INFO at start of timestep, t=817.0, dt=1.0
# gusto:INFO at start of timestep, t=818.0, dt=1.0
# gusto:INFO at start of timestep, t=819.0, dt=1.0
# gusto:INFO at start of timestep, t=820.0, dt=1.0
# gusto:INFO at start of timestep, t=821.0, dt=1.0
# gusto:INFO at start of timestep, t=822.0, dt=1.0
# gusto:INFO at start of timestep, t=823.0, dt=1.0
# gusto:INFO at start of timestep, t=824.0, dt=1.0
# gusto:INFO at start of timestep, t=825.0, dt=1.0
# gusto:INFO at start of timestep, t=826.0, dt=1.0
# gusto:INFO at start of timestep, t=827.0, dt=1.0
# gusto:INFO at start of timestep, t=828.0, dt=1.0
# gusto:INFO at start of timestep, t=829.0, dt=1.0
# gusto:INFO at start of timestep, t=830.0, dt=1.0
# gusto:INFO at start of timestep, t=831.0, dt=1.0
# gusto:INFO at start of timestep, t=832.0, dt=1.0
# gusto:INFO at start of timestep, t=833.0, dt=1.0
# gusto:INFO at start of timestep, t=834.0, dt=1.0
# gusto:INFO at start of timestep, t=835.0, dt=1.0
# gusto:INFO at start of timestep, t=836.0, dt=1.0
# gusto:INFO at start of timestep, t=837.0, dt=1.0
# gusto:INFO at start of timestep, t=838.0, dt=1.0
# gusto:INFO at start of timestep, t=839.0, dt=1.0
# gusto:INFO at start of timestep, t=840.0, dt=1.0
# gusto:INFO at start of timestep, t=841.0, dt=1.0
# gusto:INFO at start of timestep, t=842.0, dt=1.0
# gusto:INFO at start of timestep, t=843.0, dt=1.0
# gusto:INFO at start of timestep, t=844.0, dt=1.0
# gusto:INFO at start of timestep, t=845.0, dt=1.0
# gusto:INFO at start of timestep, t=846.0, dt=1.0
# gusto:INFO at start of timestep, t=847.0, dt=1.0
# gusto:INFO at start of timestep, t=848.0, dt=1.0
# gusto:INFO at start of timestep, t=849.0, dt=1.0
# gusto:INFO at start of timestep, t=850.0, dt=1.0
# gusto:INFO at start of timestep, t=851.0, dt=1.0
# gusto:INFO at start of timestep, t=852.0, dt=1.0
# gusto:INFO at start of timestep, t=853.0, dt=1.0
# gusto:INFO at start of timestep, t=854.0, dt=1.0
# gusto:INFO at start of timestep, t=855.0, dt=1.0
# gusto:INFO at start of timestep, t=856.0, dt=1.0
# gusto:INFO at start of timestep, t=857.0, dt=1.0
# gusto:INFO at start of timestep, t=858.0, dt=1.0
# gusto:INFO at start of timestep, t=859.0, dt=1.0
# gusto:INFO at start of timestep, t=860.0, dt=1.0
# gusto:INFO at start of timestep, t=861.0, dt=1.0
# gusto:INFO at start of timestep, t=862.0, dt=1.0
# gusto:INFO at start of timestep, t=863.0, dt=1.0
# gusto:INFO at start of timestep, t=864.0, dt=1.0
# gusto:INFO at start of timestep, t=865.0, dt=1.0
# gusto:INFO at start of timestep, t=866.0, dt=1.0
# gusto:INFO at start of timestep, t=867.0, dt=1.0
# gusto:INFO at start of timestep, t=868.0, dt=1.0
# gusto:INFO at start of timestep, t=869.0, dt=1.0
# gusto:INFO at start of timestep, t=870.0, dt=1.0
# gusto:INFO at start of timestep, t=871.0, dt=1.0
# gusto:INFO at start of timestep, t=872.0, dt=1.0
# gusto:INFO at start of timestep, t=873.0, dt=1.0
# gusto:INFO at start of timestep, t=874.0, dt=1.0
# gusto:INFO at start of timestep, t=875.0, dt=1.0
# gusto:INFO at start of timestep, t=876.0, dt=1.0
# gusto:INFO at start of timestep, t=877.0, dt=1.0
# gusto:INFO at start of timestep, t=878.0, dt=1.0
# gusto:INFO at start of timestep, t=879.0, dt=1.0
# gusto:INFO at start of timestep, t=880.0, dt=1.0
# gusto:INFO at start of timestep, t=881.0, dt=1.0
# gusto:INFO at start of timestep, t=882.0, dt=1.0
# gusto:INFO at start of timestep, t=883.0, dt=1.0
# gusto:INFO at start of timestep, t=884.0, dt=1.0
# gusto:INFO at start of timestep, t=885.0, dt=1.0
# gusto:INFO at start of timestep, t=886.0, dt=1.0
# gusto:INFO at start of timestep, t=887.0, dt=1.0
# gusto:INFO at start of timestep, t=888.0, dt=1.0
# gusto:INFO at start of timestep, t=889.0, dt=1.0
# gusto:INFO at start of timestep, t=890.0, dt=1.0
# gusto:INFO at start of timestep, t=891.0, dt=1.0
# gusto:INFO at start of timestep, t=892.0, dt=1.0
# gusto:INFO at start of timestep, t=893.0, dt=1.0
# gusto:INFO at start of timestep, t=894.0, dt=1.0
# gusto:INFO at start of timestep, t=895.0, dt=1.0
# gusto:INFO at start of timestep, t=896.0, dt=1.0
# gusto:INFO at start of timestep, t=897.0, dt=1.0
# gusto:INFO at start of timestep, t=898.0, dt=1.0
# gusto:INFO at start of timestep, t=899.0, dt=1.0
# gusto:INFO at start of timestep, t=900.0, dt=1.0
# gusto:INFO at start of timestep, t=901.0, dt=1.0
# gusto:INFO at start of timestep, t=902.0, dt=1.0
# gusto:INFO at start of timestep, t=903.0, dt=1.0
# gusto:INFO at start of timestep, t=904.0, dt=1.0
# gusto:INFO at start of timestep, t=905.0, dt=1.0
# gusto:INFO at start of timestep, t=906.0, dt=1.0
# gusto:INFO at start of timestep, t=907.0, dt=1.0
# gusto:INFO at start of timestep, t=908.0, dt=1.0
# gusto:INFO at start of timestep, t=909.0, dt=1.0
# gusto:INFO at start of timestep, t=910.0, dt=1.0
# gusto:INFO at start of timestep, t=911.0, dt=1.0
# gusto:INFO at start of timestep, t=912.0, dt=1.0
# gusto:INFO at start of timestep, t=913.0, dt=1.0
# gusto:INFO at start of timestep, t=914.0, dt=1.0
# gusto:INFO at start of timestep, t=915.0, dt=1.0
# gusto:INFO at start of timestep, t=916.0, dt=1.0
# gusto:INFO at start of timestep, t=917.0, dt=1.0
# gusto:INFO at start of timestep, t=918.0, dt=1.0
# gusto:INFO at start of timestep, t=919.0, dt=1.0
# gusto:INFO at start of timestep, t=920.0, dt=1.0
# gusto:INFO at start of timestep, t=921.0, dt=1.0
# gusto:INFO at start of timestep, t=922.0, dt=1.0
# gusto:INFO at start of timestep, t=923.0, dt=1.0
# gusto:INFO at start of timestep, t=924.0, dt=1.0
# gusto:INFO at start of timestep, t=925.0, dt=1.0
# gusto:INFO at start of timestep, t=926.0, dt=1.0
# gusto:INFO at start of timestep, t=927.0, dt=1.0
# gusto:INFO at start of timestep, t=928.0, dt=1.0
# gusto:INFO at start of timestep, t=929.0, dt=1.0
# gusto:INFO at start of timestep, t=930.0, dt=1.0
# gusto:INFO at start of timestep, t=931.0, dt=1.0
# gusto:INFO at start of timestep, t=932.0, dt=1.0
# gusto:INFO at start of timestep, t=933.0, dt=1.0
# gusto:INFO at start of timestep, t=934.0, dt=1.0
# gusto:INFO at start of timestep, t=935.0, dt=1.0
# gusto:INFO at start of timestep, t=936.0, dt=1.0
# gusto:INFO at start of timestep, t=937.0, dt=1.0
# gusto:INFO at start of timestep, t=938.0, dt=1.0
# gusto:INFO at start of timestep, t=939.0, dt=1.0
# gusto:INFO at start of timestep, t=940.0, dt=1.0
# gusto:INFO at start of timestep, t=941.0, dt=1.0
# gusto:INFO at start of timestep, t=942.0, dt=1.0
# gusto:INFO at start of timestep, t=943.0, dt=1.0
# gusto:INFO at start of timestep, t=944.0, dt=1.0
# gusto:INFO at start of timestep, t=945.0, dt=1.0
# gusto:INFO at start of timestep, t=946.0, dt=1.0
# gusto:INFO at start of timestep, t=947.0, dt=1.0
# gusto:INFO at start of timestep, t=948.0, dt=1.0
# gusto:INFO at start of timestep, t=949.0, dt=1.0
# gusto:INFO at start of timestep, t=950.0, dt=1.0
# gusto:INFO at start of timestep, t=951.0, dt=1.0
# gusto:INFO at start of timestep, t=952.0, dt=1.0
# gusto:INFO at start of timestep, t=953.0, dt=1.0
# gusto:INFO at start of timestep, t=954.0, dt=1.0
# gusto:INFO at start of timestep, t=955.0, dt=1.0
# gusto:INFO at start of timestep, t=956.0, dt=1.0
# gusto:INFO at start of timestep, t=957.0, dt=1.0
# gusto:INFO at start of timestep, t=958.0, dt=1.0
# gusto:INFO at start of timestep, t=959.0, dt=1.0
# gusto:INFO at start of timestep, t=960.0, dt=1.0
# gusto:INFO at start of timestep, t=961.0, dt=1.0
# gusto:INFO at start of timestep, t=962.0, dt=1.0
# gusto:INFO at start of timestep, t=963.0, dt=1.0
# gusto:INFO at start of timestep, t=964.0, dt=1.0
# gusto:INFO at start of timestep, t=965.0, dt=1.0
# gusto:INFO at start of timestep, t=966.0, dt=1.0
# gusto:INFO at start of timestep, t=967.0, dt=1.0
# gusto:INFO at start of timestep, t=968.0, dt=1.0
# gusto:INFO at start of timestep, t=969.0, dt=1.0
# gusto:INFO at start of timestep, t=970.0, dt=1.0
# gusto:INFO at start of timestep, t=971.0, dt=1.0
# gusto:INFO at start of timestep, t=972.0, dt=1.0
# gusto:INFO at start of timestep, t=973.0, dt=1.0
# gusto:INFO at start of timestep, t=974.0, dt=1.0
# gusto:INFO at start of timestep, t=975.0, dt=1.0
# gusto:INFO at start of timestep, t=976.0, dt=1.0
# gusto:INFO at start of timestep, t=977.0, dt=1.0
# gusto:INFO at start of timestep, t=978.0, dt=1.0
# gusto:INFO at start of timestep, t=979.0, dt=1.0
# gusto:INFO at start of timestep, t=980.0, dt=1.0
# gusto:INFO at start of timestep, t=981.0, dt=1.0
# gusto:INFO at start of timestep, t=982.0, dt=1.0
# gusto:INFO at start of timestep, t=983.0, dt=1.0
# gusto:INFO at start of timestep, t=984.0, dt=1.0
# gusto:INFO at start of timestep, t=985.0, dt=1.0
# gusto:INFO at start of timestep, t=986.0, dt=1.0
# gusto:INFO at start of timestep, t=987.0, dt=1.0
# gusto:INFO at start of timestep, t=988.0, dt=1.0
# gusto:INFO at start of timestep, t=989.0, dt=1.0
# gusto:INFO at start of timestep, t=990.0, dt=1.0
# gusto:INFO at start of timestep, t=991.0, dt=1.0
# gusto:INFO at start of timestep, t=992.0, dt=1.0
# gusto:INFO at start of timestep, t=993.0, dt=1.0
# gusto:INFO at start of timestep, t=994.0, dt=1.0
# gusto:INFO at start of timestep, t=995.0, dt=1.0
# gusto:INFO at start of timestep, t=996.0, dt=1.0
# gusto:INFO at start of timestep, t=997.0, dt=1.0
# gusto:INFO at start of timestep, t=998.0, dt=1.0
# gusto:INFO at start of timestep, t=999.0, dt=1.0
# gusto:INFO TIMELOOP complete. t=1000.0, tmax=1000.0
